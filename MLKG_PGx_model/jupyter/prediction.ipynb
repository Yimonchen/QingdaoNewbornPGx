# %%
import pandas as pd
import os
from collections import Counter

# %%
score_mapping = {
    "GenoCanyon_score": "GenoCanyon_score",
    "M-CAP_score": "M-CAP_score",
    "MPC_score": "MPC_score",
    "MutationAssessor_score": "MutationAssessor_score",
    "Polyphen2_HVAR_scroe": "Polyphen2_HVAR_score",
    "CADD_score": "CADD_raw",
    "DEOGEN2_score": "DEOGEN2_score",
    "FATHMM_score": "FATHMM_score",
    "Integrated_fitCons_score": "integrated_fitCons_score",
    "LRT_score": "LRT_score",
    "Provean_score": "PROVEAN_score",
    "SIFT4G_score": "SIFT4G_score",
    "VEST4_score": "VEST4_score",
}

variant_list = [
    "upstream_gene_variant",
    "splice_donor_variant",
    "NMD_transcript_variant",
    "non_coding_transcript_variant",
    "synonymous_variant",
    "splice_acceptor_variant",
    "5_prime_UTR_variant",
    "incomplete_terminal_codon_variant",
    "non_coding_transcript_exon_variant",
    "splice_region_variant",
    "splice_polypyrimidine_tract_variant",
    "intron_variant",
    "missense_variant",
    "downstream_gene_variant",
    "coding_sequence_variant",
    "3_prime_UTR_variant"
]

all_feat = list(score_mapping.values()) + ["APF_score", "LoFtool"]

# %%
os.chdir("d:/functional-prediction")
# df = pd.read_csv("output/NovelCommonSNP.csv")
df = pd.read_csv("output/allSNP.csv")
# df = pd.read_csv("output/KnownRareSNP.csv")
# df = pd.read_csv("output/NovelRareSNP.csv")

# %%
df = df[all_feat]

# %%
feat_count_list = []
for col in df.columns:
    col_count = df[col].notnull().sum()
    feat_count_list.append({"feat": col, "count": col_count, "ratio": round(col_count / len(df), 4)})
    
df_count = pd.DataFrame(feat_count_list)

df_count = df_count.sort_values(by=["count"])

feat_list = df_count["feat"].values

print(feat_list)
# Out:
# ['DEOGEN2_score' 'M-CAP_score' 'MPC_score' 'MutationAssessor_score'
#  'LRT_score' 'FATHMM_score' 'PROVEAN_score' 'Polyphen2_HVAR_score'
#  'integrated_fitCons_score' 'VEST4_score' 'SIFT4G_score' 'LoFtool'
#  'APF_score' 'GenoCanyon_score' 'CADD_raw']

# %%
df_count.to_csv("output/column_ratio.tsv", sep="\t", index=False)

# %%
df_binary = pd.read_csv("output/qd_binary_score.csv")
len(df_binary)
# Out:
# 487989

# %%
col_dict = {
    "column": [],
    "positive": [],
    "ratio": []
}
for col in df_binary.columns:
    if "score_eliminate_" in col:
        col_list = df_binary[col].values
        col_list = [1 if x > 0.5 else 0 for x in col_list]
        col_sum = sum(col_list)
        col_ratio = col_sum / len(col_list)
        
        col_dict["column"].append(col)
        col_dict["positive"].append(col_sum)
        col_dict["ratio"].append(col_ratio)

# %%
df_eliminate = pd.DataFrame(col_dict)
df_eliminate.to_csv("output/column_eliminate.tsv", sep="\t", index=False)

# %%
df_lof = pd.read_csv("data/LoFtool_scores.txt", sep="\t")
lof_dict = dict(zip(
    df_lof["Gene"].values,
    df_lof["LoFtool_percentile"].values
))

# %%
gene_dict = {
    "gene": [],
    "variant_count": [],
    "positive": [],
    "ratio": [],
    "LOF": []
}
for gene, content in df_binary[["gene", "score_eliminate_0"]].groupby(["gene"]):
    col_list = content["score_eliminate_0"].values
    col_list = [1 if x > 0.5 else 0 for x in col_list]
    col_sum = sum(col_list)
    col_len = len(col_list)
    col_ratio = col_sum / col_len
    
    gene_dict["gene"].append(gene)
    gene_dict["variant_count"].append(col_len)
    gene_dict["positive"].append(col_sum)
    gene_dict["ratio"].append(col_ratio)
    gene_dict["LOF"].append(lof_dict.get(gene, ""))

# %%
len(gene_dict["gene"])
# Out:
# 249

# %%
df_gene_ratio = pd.DataFrame(gene_dict).sort_values(by=["ratio"], ascending=False)
df_gene_ratio[:50]
# Out:
#         gene  variant_count  positive     ratio    LOF
# 84   CYP2C19           4304      4272  0.992565  0.923
# 215  SLCO1B1           4286      4241  0.989501  0.994
# 83   CYP2C18           2132      2099  0.984522  0.857
# 86    CYP2C9           2183      2144  0.982135  0.903
# 214  SLCO1A2           4821      4707  0.976353  0.994
# 238   UGT2A1           2716      2642  0.972754  0.903
# 128    GSTA1            602       583  0.968439   0.89
# 85    CYP2C8           1292      1249  0.966718  0.924
# 22      ADH7            793       765  0.964691  0.972
# 129    GSTA2            578       555  0.960208  0.846
# 105   CYP4Z1           1599      1529  0.956223  0.797
# 152     NAT2            421       400  0.950119  0.816
# 241  UGT2B28            685       650  0.948905  0.884
# 239  UGT2B11            675       638  0.945185  0.968
# 242   UGT2B4            538       506  0.940520  0.944
# 130    GSTA3            488       457  0.936475  0.755
# 16     ADH1A            397       370  0.931990  0.895
# 216  SLCO1B3           4806      4469  0.929879  0.793
# 81    CYP2B6           1231      1143  0.928513  0.888
# 120     FMO2            979       896  0.915220  0.941
# 132    GSTA5            613       561  0.915171  0.849
# 186  SLC13A1           2897      2644  0.912668  0.899
# 185  SLC10A2            941       847  0.900106  0.966
# 151     NAT1           2642      2362  0.894020  0.996
# 240  UGT2B15            876       778  0.888128  0.887
# 98   CYP4A11            498       440  0.883534  0.904
# 19      ADH4            640       564  0.881250   0.93
# 121     FMO3           1075       945  0.879070  0.997
# 93    CYP3A4            787       688  0.874206   0.93
# 188  SLC15A2           1808      1571  0.868916  0.979
# 80    CYP2A7            457       391  0.855580  0.959
# 200  SLC22A6            333       280  0.840841  0.705
# 133    GSTM2            288       241  0.836806  0.921
# 65   CYP11B2            388       324  0.835052  0.917
# 89    CYP2F1            623       509  0.817014  0.824
# 18     ADH1C            588       473  0.804422
# 107   CYP7A1            365       290  0.794521   0.73
# 25     AKAP9           5780      4554  0.787889  0.933
# 59     CHST9           9173      7197  0.784585  0.749
# 78   CYP2A13            411       314  0.763990  0.785
# 202  SLC22A8            802       598  0.745636  0.814
# 71   CYP20A1           2613      1929  0.738232  0.865
# 205  SLC28A2            732       534  0.729508  0.762
# 166     PON3           1261       908  0.720063  0.744
# 95    CYP3A5            944       673  0.712924  0.909
# 220  SLCO5A1           6032      4290  0.711207  0.772
# 96    CYP3A7            964       676  0.701245  0.906
# 76   CYP27A1           1194       826  0.691792  0.705
# 187  SLC15A1           2780      1892  0.680576  0.883
# 94   CYP3A43           1299       869  0.668976  0.913

# %%
df_gene_ratio[50:100]
# Out:
#            gene  variant_count  positive     ratio       LOF
# 114       EPHX2           2119      1413  0.666824     0.949
# 172       PROS1           3659      2431  0.664389      0.27
# 149        MGMT          13372      8803  0.658316     0.823
# 79       CYP2A6            403       263  0.652605     0.916
# 122        FMO4            964       625  0.648340
# 104      CYP4F8            638       413  0.647335
# 123        FMO5           1402       904  0.644793     0.978
# 92      CYP39A1           3624      2300  0.634658     0.428
# 131       GSTA4            590       374  0.633898     0.736
# 15          ACE            975       614  0.629744     0.822
# 99       CYP4B1            799       502  0.628285     0.455
# 237  UGT1Agroup           5955      3714  0.623678
# 243      UGT2B7            659       409  0.620637     0.913
# 233       TOP2A            890       549  0.616854     0.689
# 100     CYP4F11           1000       616  0.616000     0.189
# 28        ALDH2           1511       930  0.615486     0.727
# 40         BCHE           2392      1453  0.607441     0.416
# 102      CYP4F2            811       492  0.606658     0.404
# 195    SLC22A14            531       313  0.589454     0.812
# 234        TPMT            944       555  0.587924     0.703
# 119        FMO1            916       532  0.580786     0.688
# 191     SLC22A1           1404       813  0.579060      0.92
# 11        ABCC9           4635      2682  0.578641    0.0477
# 193    SLC22A12            568       325  0.572183     0.166
# 136       GSTM5            275       156  0.567273     0.863
# 101     CYP4F12           1146       634  0.553229     0.442
# 32         AOX1           2980      1618  0.542953     0.979
# 244        UGT8           2589      1405  0.542681     0.295
# 103      CYP4F3            869       459  0.528193     0.328
# 174       PTGIS           2401      1262  0.525614     0.936
# 134       GSTM3            260       136  0.523077     0.827
# 124       FMO6P            885       461  0.520904
# 55        CHST5            314       162  0.515924     0.298
# 72      CYP21A2            172        84  0.488372
# 181       SCN1A           5444      2634  0.483835  0.000138
# 115       ERCC1            373       180  0.482574     0.861
# 192    SLC22A11            698       333  0.477077     0.836
# 204     SLC28A1           2789      1313  0.470778     0.876
# 226     SULT1C2            731       344  0.470588      0.36
# 54        CHST4            479       217  0.453027     0.151
# 164        PON1            941       423  0.449522     0.787
# 113       EPHX1           1552       693  0.446521     0.843
# 232      TBXAS1           7306      3210  0.439365     0.983
# 82      CYP2B7P           1085       468  0.431336
# 108      CYP7B1           6580      2786  0.423404      0.48
# 206     SLC28A3           2314       924  0.399309     0.964
# 118        FAAH            746       292  0.391421     0.812
# 158      NUDT15            330       128  0.387879     0.755
# 0         ABCB1           7279      2781  0.382058    0.0227
# 135       GSTM4            215        81  0.376744     0.971

# %%
df_gene_ratio[100:150]
# Out:
#          gene  variant_count  positive     ratio      LOF
# 20       ADH5            598       223  0.372910    0.826
# 246       XDH           3333      1217  0.365137    0.922
# 223   SULT1A1            259        90  0.347490    0.205
# 170   PPP1R9A          12886      4421  0.343086    0.146
# 87     CYP2D6            311       106  0.340836
# 165      PON2            965       325  0.336788    0.823
# 143     IL12B            546       182  0.333333     0.69
# 58      CHST8           3822      1196  0.312925    0.629
# 196   SLC22A2           1745       540  0.309456    0.614
# 184   SLC10A1            818       253  0.309291     0.99
# 17      ADH1B            377       115  0.305040    0.661
# 203  SLC25A27            868       252  0.290323    0.495
# 66    CYP17A1            242        70  0.289256    0.455
# 60       COMT           1327       363  0.273549    0.748
# 64    CYP11B1            413       111  0.268765    0.508
# 74    CYP26A1            136        36  0.264706    0.686
# 183  SERPINC1            450       119  0.264444
# 159      ORM1            175        46  0.262857    0.855
# 219   SLCO4A1           1644       410  0.249392    0.726
# 111      DPYD          31252      7765  0.248464     0.11
# 229   SULT2A1            725       179  0.246897    0.615
# 155     NR1I2           1336       312  0.233533
# 228   SULT1E1            720       165  0.229167    0.484
# 62       CROT           1689       385  0.227946    0.113
# 248       XPC           1278       289  0.226135     0.96
# 42       CASR           3686       798  0.216495   0.0053
# 116        F2            755       160  0.211921    0.125
# 175      QPRT            841       175  0.208086
# 154      NQO1            660       137  0.207576    0.989
# 34       ARNT           2338       465  0.198888     0.54
# 69     CYP1A2            316        62  0.196203     0.56
# 230   SULT2B1           2341       449  0.191798   0.0652
# 46       CES2            400        76  0.190000     0.93
# 160      ORM2            154        29  0.188312    0.874
# 61       CPS1           4032       744  0.184524   0.0148
# 68     CYP1A1            216        38  0.175926    0.627
# 36        ASL            726       124  0.170799   0.0497
# 8       ABCC5           3599       603  0.167547    0.146
# 222       SPN            343        57  0.166181    0.595
# 97    CYP46A1           1590       264  0.166038    0.259
# 201   SLC22A7            273        39  0.142857
# 137     GSTO1            387        55  0.142119    0.931
# 163      PNMT            110        14  0.127273    0.674
# 23      ADRB1            125        14  0.112000
# 189   SLC16A1           1529       165  0.107914    0.173
# 2       ABCB4           2426       261  0.107585   0.0172
# 35       ARSA            286        30  0.104895  0.00558
# 110       DCK           1483       154  0.103844    0.263
# 150      NAGS            178        18  0.101124    0.216
# 109    CYP8B1            143        14  0.097902    0.609

# %%
df_gene_ratio[150:200]
# Out:
#          gene  variant_count  positive     ratio      LOF
# 180      RYR1           6804       612  0.089947  0.00248
# 148    METTL1            112        10  0.089286    0.409
# 117        F5           2546       221  0.086803   0.0863
# 139     GSTZ1            431        37  0.085847    0.929
# 70     CYP1B1            354        30  0.084746    0.351
# 126       GBA            390        32  0.082051  0.00827
# 75    CYP26C1            316        25  0.079114
# 21       ADH6            503        38  0.075547
# 9       ABCC6           3003       221  0.073593   0.0194
# 77    CYP27B1            184        13  0.070652    0.456
# 146      MAOB           3155       218  0.069097   0.0976
# 194  SLC22A13            422        29  0.068720    0.661
# 73    CYP24A1            817        55  0.067319    0.973
# 145      MAOA           2307       154  0.066753
# 43       CBR1            155        10  0.064516    0.372
# 224   SULT1A2            272        17  0.062500    0.248
# 236      TYMS            655        40  0.061069    0.173
# 52      CHST2            181        11  0.060773    0.182
# 47       CFTR           5910       358  0.060575   0.0235
# 173    PRSS53            216        13  0.060185
# 106   CYP51A1            716        42  0.058659     0.39
# 141      HNMT           1784       104  0.058296    0.483
# 41    CACNA1S           3139       175  0.055750     0.03
# 56      CHST6            998        53  0.053106     0.15
# 48      CHST1            741        36  0.048583   0.0319
# 67    CYP19A1           4687       223  0.047578    0.495
# 138     GSTP1            148         7  0.047297    0.722
# 208   SLC29A2            404        19  0.047030    0.526
# 90     CYP2J2           1132        51  0.045053    0.648
# 29    ALDH3A1            345        15  0.043478    0.313
# 88     CYP2E1            466        20  0.042918    0.555
# 167       POR           3238       131  0.040457    0.329
# 207   SLC29A1            602        24  0.039867    0.513
# 24        AHR           1726        68  0.039397    0.393
# 156     NR1I3            331        13  0.039275   0.0107
# 13      ABCG2           2413        94  0.038956    0.454
# 91     CYP2S1            617        23  0.037277    0.562
# 14       ABL2           4871       168  0.034490     0.68
# 245    VKORC1            147         5  0.034014
# 247      XIAP           1971        67  0.033993    0.245
# 30    ALDH3A2           1043        35  0.033557    0.251
# 140     HMGCR            759        25  0.032938    0.203
# 144     IL23A             31         1  0.032258     0.27
# 1      ABCB11           3913       116  0.029645
# 37       ASS1           2482        71  0.028606   0.0989
# 171      PROC            461        13  0.028200    0.097
# 6       ABCC3           2323        65  0.027981   0.0379
# 49     CHST10           1006        28  0.027833    0.593
# 10      ABCC8           3291        90  0.027347   0.0423
# 177     RPL13            405        11  0.027160

# %%
df_gene_ratio[200:250]
# Out:
#          gene  variant_count  positive     ratio     LOF
# 147     MAT1A            682        18  0.026393  0.0748
# 209    SLC5A6            536        14  0.026119   0.125
# 44       CBR3            465        12  0.025806   0.601
# 190   SLC19A1           1423        36  0.025299   0.187
# 197   SLC22A3           3616        89  0.024613   0.682
# 199   SLC22A5            948        22  0.023207   0.403
# 221      SPG7           2837        64  0.022559   0.103
# 45        CDA           1164        24  0.020619   0.229
# 5       ABCC2           2377        49  0.020614  0.0978
# 39      ATP7B           2970        61  0.020539   0.034
# 33      APOA2             51         1  0.019608   0.359
# 235     TPSG1            319         6  0.018809   0.128
# 217   SLCO2B1           2146        39  0.018173   0.606
# 176    RALBP1           2367        43  0.018166    0.39
# 57      CHST7            722        13  0.018006
# 7       ABCC4          10951       197  0.017989  0.0441
# 227   SULT1C4            392         7  0.017857   0.532
# 3       ABCB7           2500        43  0.017200  0.0561
# 162     PGAP3            645        11  0.017054   0.177
# 125      G6PD            602        10  0.016611  0.0169
# 51     CHST13            806        12  0.014888
# 213    SLC7A8           2237        33  0.014752   0.135
# 198   SLC22A4           1630        24  0.014724   0.538
# 53      CHST3           1921        25  0.013014   0.133
# 63    CYP11A1           1107        14  0.012647   0.589
# 31      ANKK1            485         6  0.012371   0.549
# 210    SLC6A6           3587        44  0.012267   0.301
# 178      RRM1           1581        19  0.012018   0.149
# 212    SLC7A7           2088        25  0.011973   0.114
# 12      ABCG1           3373        36  0.010673    0.41
# 127       GLA            288         3  0.010417
# 38      ATP7A           3510        31  0.008832  0.0197
# 161       OTC           1861        16  0.008598
# 231   SULT4A1           1772        15  0.008465
# 27    ALDH1A1           1820        15  0.008242   0.271
# 50     CHST11          11363        85  0.007480   0.314
# 182  SERPINA7            138         1  0.007246   0.119
# 153      NNMT            576         4  0.006944    0.62
# 157     NR3C1           4338        30  0.006916  0.0657
# 4       ABCC1           9002        56  0.006221  0.0802
# 26        ALB            537         3  0.005587   0.648
# 169     PPARG           2898        16  0.005521  0.0635
# 179      RXRA           5885        27  0.004588  0.0143
# 168     PPARD           3307        15  0.004536  0.0103
# 211    SLC7A5           2327        10  0.004297  0.0798
# 112      EGFR           7353        30  0.004080  0.0455
# 225   SULT1B1           1289         5  0.003879   0.552
# 142     HPRT1           1057         4  0.003784   0.128
# 218   SLCO3A1          13521        45  0.003328   0.132

# %%
df_gene_ratio.to_csv("output/gene_conservative_ratio.tsv", sep="\t", index=False)

# %%
df_multi = pd.read_csv("output/qd_multi_score.csv")
len(df_multi)
# Out:
# 51645

# %%
result = df_multi["score_eliminate_0"].values

# %%
c_dict = Counter(result)
c_dict["normal function"]
# Out:
# 30692

# %%
(51645 - 30692) / 51645
# Out:
# 0.40571207280472454
